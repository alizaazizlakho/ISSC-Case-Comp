# %%
import pandas as pd
import numpy as np

# %%
profile_data = pd.read_csv("neighbourhood-profiles-2016-csv.csv")

# %%
profile_data.head()
# Out:
#    _id  ...      Yorkdale-Glen Park
# 0    1  ...                      31
# 1    2  ...  Emerging Neighbourhood
# 2    3  ...                  14,804
# 3    4  ...                  14,687
# 4    5  ...                   0.80%
#
# [5 rows x 146 columns]

# %%
profile_data.describe
# Out:
# <bound method NDFrame.describe of        _id  ...      Yorkdale-Glen Park
# 0        1  ...                      31
# 1        2  ...  Emerging Neighbourhood
# 2        3  ...                  14,804
# 3        4  ...                  14,687
# 4        5  ...                   0.80%
# ...    ...  ...                     ...
# 2378  2379  ...                   1,345
# 2379  2380  ...                     580
# 2380  2381  ...                     445
# 2381  2382  ...                     135
# 2382  2383  ...                     775
#
# [2383 rows x 146 columns]>

# %%
#Generating a new dataframe with only Ethnic information
profile_data = profile_data.set_index("Category")
ethnic_data = profile_data.drop(["Neighbourhood Information", "Population", "Families, households and marital status", "Income", "Language", "Visible minority", "Ethnic origin", "Aboriginal peoples", "Housing", "Education", "Language of work", "Labour", "Journey to work", "Mobility"])

# %%
ethnic_data
# Out:
#                               _id  ... Yorkdale-Glen Park
# Category                           ...
# Immigration and citizenship  1139  ...                285
# Immigration and citizenship  1145  ...             14,025
# Immigration and citizenship  1146  ...             12,160
# Immigration and citizenship  1147  ...              2,325
# Immigration and citizenship  1149  ...              9,835
# ...                           ...  ...                ...
# Immigration and citizenship  1298  ...                930
# Immigration and citizenship  1299  ...                910
# Immigration and citizenship  1300  ...              1,910
# Immigration and citizenship  1301  ...                825
# Immigration and citizenship  1302  ...                 35
#
# [154 rows x 145 columns]

# %%
ethnic_data = ethnic_data.set_index("Topic")

# %%
country = ethnic_data.drop(["Citizenship", "Immigrant status and period of immigration", "Age at immigration", "Recent immigrants by selected place of birth", "Generation status", "Admission category and applicant type"])

# %%
country.head()
# Out:
#                                         _id  ... Yorkdale-Glen Park
# Topic                                        ...
# Immigrants by selected place of birth  1139  ...                285
# Immigrants by selected place of birth  1169  ...              7,270
# Immigrants by selected place of birth  1170  ...              1,510
# Immigrants by selected place of birth  1171  ...                 90
# Immigrants by selected place of birth  1172  ...                105
#
# [5 rows x 144 columns]

# %%
country = country.set_index("Characteristic")

# %%
country.head()
# Out:
#                                                      _id  ... Yorkdale-Glen Park
# Characteristic                                            ...
#   Africa                                            1139  ...                285
# Total - Selected places of birth for the immigr...  1169  ...              7,270
#   Americas                                          1170  ...              1,510
#     Brazil                                          1171  ...                 90
#     Colombia                                        1172  ...                105
#
# [5 rows x 143 columns]

# %%
country = country.drop(columns=["_id", "Data Source"])

# %%
country
# Out:
#                                                    City of Toronto  ... Yorkdale-Glen Park
# Characteristic                                                      ...
#   Africa                                                    77,445  ...                285
# Total - Selected places of birth for the immigr...       1,266,005  ...              7,270
#   Americas                                                 212,010  ...              1,510
#     Brazil                                                   7,025  ...                 90
#     Colombia                                                 8,715  ...                105
#     El Salvador                                              6,955  ...                 45
#     Guyana                                                  34,490  ...                290
#     Haiti                                                    1,850  ...                  0
# ...

# %%
country.to_csv('ethnic_origins.csv')
